# %% [markdown]
# ![Logo_2.png](attachment:Logo_2.png)

# %% [markdown]
# # Stützenbemessung nach der DIN EN 1995-1-1 Abs. 6.3

# %% [markdown]
# ## Ersatzstabverfahren
#
# Das Ersatzstabverfahren ist ein vereinfachtes Nachweisverfahren, welches die Schnittgrößen nach der Theorie I. Ordnung, also am unverformten System, ermittelt und dabei die geometrische Nichtlinearität für die Versagensfälle Knicken und Kippen anhand von Beiwerten berücksichtigt. Üblicherweise kommt dieses Verfahren bei der Betrachtung von Einzelstäben zum Einsatz.

# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ### Eingangswerte

# %%
# Bibliotheken
from math import sqrt, pi    # Mathematische Funktionen
import matplotlib.pyplot as plt    # Erstellen von Grafiken
import pandas as pd    # Erstellen von Tabellen
import handcalcs.render    # Darstellung formattierter Gleichungen

# Sytem und Geometrie
Lagerung = 'Pendelstütze'
L = 3    # m - Länge
b = 0.5    # m - Breite
h = 0.4    # m - Höhe

# Einwirkung
N_ed = 2000    # kN - Normalkraft
M_yd = 50    # kNm - Moment um y-Achse
M_zd = 30    # kNm - Moment um z-Achse

# Festigkeitskennwerte
Güte = 'GL28h'    # Holzgüte
f_c0k = 28*1000    # $kN/m^2$ - Druck  
f_myk = 28*1000    # $kN/m^2$ - Biegung
f_mzk = 28*1000    # $kN/m^2$ - Biegung
E_0mean = 12500*1000    # $kN/m^2$ - E-Modul  
E_05 = 9600*1000    # $kN/m^2$ - E-Modul  
G_05 = 540*1000    # $kN/m^2$ - Schubmodul  

# Widerstandbeiwerte
k_mod = 0.8    # Modifikationsbeiwert
gamma = 1.3    # Teilsicherheitsbeiwert

# %% [markdown]
# #### System

# %%
# %%render
# Lagerung
# Out:
# \[
# \begin{aligned}
# \mathrm{Lagerung} &= \mathrm{Pendelstütze} \;
# \end{aligned}
# \]

# %%
# if-Abfrage zur Bestimmung von beta
if Lagerung == 'Pendelstütze':
    beta = 1
elif Lagerung == 'Kragstütze':
    beta = 2
elif Lagerung == 'Eingespannt (u/o)':
    beta = 0.7
else:
    beta = 0.5

# %% [markdown]
# #### Geometrie

# %%
# %%render params 1
# L    # m - Länge
# b    # m - Breite
# h    # m - Höhe
# Out:
# \[
# \begin{aligned}
# L &= 3 \; \;\textrm{(m - Länge)}
#  &b &= 0.5 \; \;\textrm{(m - Breite)}
#  &h &= 0.4 \; \;\textrm{(m - Höhe)}
# \\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# #### Bemessungswerte der Einwirkung

# %%
# %%render params 1
# N_ed    # kN - Normalkraft
# M_yd    # kNm - Moment um y-Achse
# M_zd    # kNm - Moment um z-Achse
# Out:
# \[
# \begin{aligned}
# N_{ed} &= 2000 \; \;\textrm{(kN - Normalkraft)}
#  &M_{yd} &= 50 \; \;\textrm{(kNm - Moment um y-Achse)}
#  &M_{zd} &= 30 \; \;\textrm{(kNm - Moment um z-Achse)}
# \\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# #### Charakteristische Festigkeitswerte

# %%
# %%render params 1
# Güte    # Holzgüte
# f_c0k    # $kN/m^2$ - Druck
# f_myk    # $kN/m^2$ - Biegung
# f_mzk    # $kN/m^2$ - Biegung
# E_0mean    # $kN/m^2$ - E-Modul
# Out:
# \[
# \begin{aligned}
# \mathrm{Güte} &= \mathrm{GL28h} \; \;\textrm{(Holzgüte)}
#  &f_{c0k} &= 28000 \; \;\textrm{($kN/m^2$ - Druck)}
#  &f_{myk} &= 28000 \; \;\textrm{($kN/m^2$ - Biegung)}
# \\[10pt]
#  f_{mzk} &= 28000 \; \;\textrm{($kN/m^2$ - Biegung)}
#  &E_{0mean} &= 12500000 \; \;\textrm{($kN/m^2$ - E-Modul)}
# \end{aligned}
# \]

# %% [markdown]
# #### Widerstandsbeiwerte

# %%
# %%render
# k_mod    # Modifikationsbeiwert
# gamma    # Teilsicherheitsbeiwert
# xi = k_mod/gamma    # Abminderungsbeiwert
# Out:
# \[
# \begin{aligned}
# k_{mod} &= 0.800 \; \;\textrm{(Modifikationsbeiwert)}
# \\[10pt]
# \gamma &= 1.300 \; \;\textrm{(Teilsicherheitsbeiwert)}
# \\[10pt]
# \xi &= \frac{ k_{mod} }{ \gamma }  = \frac{ 0.800 }{ 1.300 } &= 0.615 \; \;\textrm{(Abminderungsbeiwert)}
# \end{aligned}
# \]

# %% [markdown]
# ### Berechnung

# %% [markdown]
# #### Querschnittsparameter

# %%
# %%render params 3
# A = b*h    # $m^2$ - Querschnitt
# Out:
# \[
# \begin{aligned}
# A &= 0.200 \; \;\textrm{($m^2$ - Querschnitt)}
# \end{aligned}
# \]

# %%
# %%render params 5
# I_y = (b*h**3)/12    # $m^4$ - FTM
# w_y = (b*h**2)/6    # $m^3$ - Widerstandsmoment
# i_y = h/sqrt(12)    # $m$ - polares Trägheitsmoment
#
#
# I_z = (h*b**3)/12    # $m^4$ - FTM
# w_z = (h*b**2)/6    # $m^3$ - Widerstandsmoment
# i_z = b/sqrt(12)    # $m$ - polares Trägheitsmoment
# Out:
# \[
# \begin{aligned}
# I_{y} &= 0.00267 \; \;\textrm{($m^4$ - FTM)}
#  &w_{y} &= 0.01333 \; \;\textrm{($m^3$ - Widerstandsmoment)}
#  &i_{y} &= 0.11547 \; \;\textrm{($m$ - polares Trägheitsmoment)}
# \\[10pt]
#  I_{z} &= 0.00417 \; \;\textrm{($m^4$ - FTM)}
#  &w_{z} &= 0.01667 \; \;\textrm{($m^3$ - Widerstandsmoment)}
#  &i_{z} &= 0.14434 \; \;\textrm{($m$ - polares Trägheitsmoment)}
# \\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# #### Bemessungswerte der Festigkeit

# %%
# %%render
# f_c0d = f_c0k*xi    # $N/mm^2$ - Bemessungswert der Druckfestigkeit
# f_myd = f_myk*xi    # $N/mm^2$ - Bemessungswert der Biegefestigkeit
# f_mzd = f_mzk*xi    # $N/mm^2$ - Bemessungswert der Biegefestigkeit
# Out:
# \[
# \begin{aligned}
# f_{c0d} &= f_{c0k} \cdot \xi  = 28000 \cdot 0.615 &= 17230.769 \; \;\textrm{($N/mm^2$ - Bemessungswert der Druckfestigkeit)}
# \\[10pt]
# f_{myd} &= f_{myk} \cdot \xi  = 28000 \cdot 0.615 &= 17230.769 \; \;\textrm{($N/mm^2$ - Bemessungswert der Biegefestigkeit)}
# \\[10pt]
# f_{mzd} &= f_{mzk} \cdot \xi  = 28000 \cdot 0.615 &= 17230.769 \; \;\textrm{($N/mm^2$ - Bemessungswert der Biegefestigkeit)}
# \end{aligned}
# \]

# %% [markdown]
# #### Spannungen

# %%
# %%render 5
# sigma_cd = N_ed/(A)    # $kN/m^2$ - Druckspannung
#
# sigma_myd = M_yd/w_y    # $kN/m^2$ - Biegespannung um y-Achse
# sigma_mzd = M_zd/w_z    # $kN/m^2$ - Biegespannung um z-Achse
# Out:
# \[
# \begin{aligned}
# \sigma_{cd} &= \frac{ N_{ed} }{ A }  = \frac{ 2000 }{ 0.20000 } &= 10000.00000 \; \;\textrm{($kN/m^2$ - Druckspannung)}
# \\[10pt]
# \sigma_{myd} &= \frac{ M_{yd} }{ w_{y} }  = \frac{ 50 }{ 0.01333 } &= 3750.00000 \; \;\textrm{($kN/m^2$ - Biegespannung um y-Achse)}
# \\[10pt]
# \sigma_{mzd} &= \frac{ M_{zd} }{ w_{z} }  = \frac{ 30 }{ 0.01667 } &= 1800.00000 \; \;\textrm{($kN/m^2$ - Biegespannung um z-Achse)}
# \end{aligned}
# \]

# %% [markdown]
# #### Knicken
# *DIN EN 1995-1-1 Abs. 6.3.2*

# %%
# %%render
# l_ef = beta*L    # m - Knicklänge
# Out:
# \[
# \begin{aligned}
# l_{ef} &= \beta \cdot L  = 1 \cdot 3 &= 3 \; \;\textrm{(m - Knicklänge)}
# \end{aligned}
# \]

# %% [markdown]
# **um y-Achse**

# %%
# %%render
# lamb_y = (beta*L)/i_y    # Schlankheitsgrad
# lamb_rel_y = lamb_y/pi*sqrt(f_c0k/E_05)    # bezogene Schlankheit
# k_y_y = 0.5*(1+0.1*(lamb_rel_y-0.3)+lamb_rel_y**2)    # Beiwert
# k_c_y = 1/(k_y_y+sqrt(k_y_y**2-lamb_rel_y**2))    # Knickbeiwert
# Out:
# \[
# \begin{aligned}
# \lambda_{y} &= \frac{ \beta \cdot L }{ i_{y} }  = \frac{ 1 \cdot 3 }{ 0.115 } &= 25.981 \; \;\textrm{(Schlankheitsgrad)}
# \\[10pt]
# \lambda_{rel_{y}} &= \frac{ \lambda_{y} }{ \pi } \cdot \sqrt { \frac{ f_{c0k} }{ E_{05} } }  = \frac{ 25.981 }{ 3.142 } \cdot \sqrt { \frac{ 28000 }{ 9600000 } } &= 0.447 \; \;\textrm{(bezogene Schlankheit)}
# \\[10pt]
# k_{y_{y}} &= 0.5 \cdot \left( 1 + 0.1 \cdot \left( \lambda_{rel_{y}} - 0.3 \right) + \left( \lambda_{rel_{y}} \right) ^{ 2 } \right) \\&= 0.5 \cdot \left( 1 + 0.1 \cdot \left( 0.447 - 0.3 \right) + \left( 0.447 \right) ^{ 2 } \right) \\&= 0.607 \; \;\textrm{(Beiwert)}\\[10pt]
# \\[10pt]
# k_{c_{y}} &= \frac{ 1 }{ k_{y_{y}} + \sqrt { \left( k_{y_{y}} \right) ^{ 2 } - \left( \lambda_{rel_{y}} \right) ^{ 2 } } }  = \frac{ 1 }{ 0.607 + \sqrt { \left( 0.607 \right) ^{ 2 } - \left( 0.447 \right) ^{ 2 } } } &= 0.982 \; \;\textrm{(Knickbeiwert)}
# \end{aligned}
# \]

# %% [markdown]
# **um z-Achse**

# %%
# %%render
# lamb_z = (beta*L)/i_z    # Schlankheitsgrad
# lamb_rel_z = lamb_z/pi*sqrt(f_c0k/E_05)    # bezogene Schlankheit
# k_y_z = 0.5*(1+0.1*(lamb_rel_z-0.3)+lamb_rel_z**2)    # Beiwert
# k_c_z = 1/(k_y_z+sqrt(k_y_z**2-lamb_rel_z**2))    # Knickbeiwert
# Out:
# \[
# \begin{aligned}
# \lambda_{z} &= \frac{ \beta \cdot L }{ i_{z} }  = \frac{ 1 \cdot 3 }{ 0.144 } &= 20.785 \; \;\textrm{(Schlankheitsgrad)}
# \\[10pt]
# \lambda_{rel_{z}} &= \frac{ \lambda_{z} }{ \pi } \cdot \sqrt { \frac{ f_{c0k} }{ E_{05} } }  = \frac{ 20.785 }{ 3.142 } \cdot \sqrt { \frac{ 28000 }{ 9600000 } } &= 0.357 \; \;\textrm{(bezogene Schlankheit)}
# \\[10pt]
# k_{y_{z}} &= 0.5 \cdot \left( 1 + 0.1 \cdot \left( \lambda_{rel_{z}} - 0.3 \right) + \left( \lambda_{rel_{z}} \right) ^{ 2 } \right) \\&= 0.5 \cdot \left( 1 + 0.1 \cdot \left( 0.357 - 0.3 \right) + \left( 0.357 \right) ^{ 2 } \right) \\&= 0.567 \; \;\textrm{(Beiwert)}\\[10pt]
# \\[10pt]
# k_{c_{z}} &= \frac{ 1 }{ k_{y_{z}} + \sqrt { \left( k_{y_{z}} \right) ^{ 2 } - \left( \lambda_{rel_{z}} \right) ^{ 2 } } }  = \frac{ 1 }{ 0.567 + \sqrt { \left( 0.567 \right) ^{ 2 } - \left( 0.357 \right) ^{ 2 } } } &= 0.993 \; \;\textrm{(Knickbeiwert)}
# \end{aligned}
# \]

# %% [markdown]
# ### Kippen
# *DIN EN 1995-1-1 Abs. 6.3.3*

# %%
index = [w_y, w_z].index(max(w_y, w_z))
L_I = [I_y,I_z]
L_w = [w_y,w_z]
L_bh = [[b,h],[h,b]]
L_fmk = [f_myk,f_mzk]
L_k_crit = [1,1]

# %%
# %%render params
# Achse_stark = ['y','z'][index]
#
# w = L_w[index]
# b = L_bh[index][0]
# h = L_bh[index][1]
# f_mk = L_fmk[index]
# Out:
# \[
# \begin{aligned}
# \mathrm{Achse}_{stark} &= z \;
#  &w &= 0.017 \;
#  &b &= 0.400 \;
# \\[10pt]
#  h &= 0.500 \;
#  &f_{mk} &= 28000 \;
# \end{aligned}
# \]

# %%
# %%render
# lamb_relm = sqrt(l_ef/(pi*b**2))*sqrt(f_mk/sqrt(E_05*G_05))    # bez. Schlankheitsgrad
#
# if lamb_relm <= 0.75: k_crit = 1    # Kippbeiwert
# elif lamb_relm > 0.75 and lamb_relm < 1.4: k_crit = 1.56-0.75*lamb_relm    # Kippbeiwert
# elif lamb_relm > 1.4: k_crit = 1/lamb_relm**2    # Kippbeiwert
# Out:
# \[
# \begin{aligned}
# \lambda_{relm} &= \sqrt { \frac{ l_{ef} }{ \pi \cdot \left( b \right) ^{ 2 } } } \cdot \sqrt { \frac{ f_{mk} }{ \sqrt { E_{05} \cdot G_{05} } } } \\&= \sqrt { \frac{ 3 }{ 3.142 \cdot \left( 0.400 \right) ^{ 2 } } } \cdot \sqrt { \frac{ 28000 }{ \sqrt { 9600000 \cdot 540000 } } } \\&= 0.271 \; \;\textrm{(bez. Schlankheitsgrad)}\\[10pt]
# \\[10pt]
# &\text{Since, } \lambda_{relm} \leq 0.75 \rightarrow \left( 0.271 \leq 0.75 \right) : \; \;\textrm{(Kippbeiwert)} \end{aligned}
# \]
# \[
# \begin{aligned}
# k_{crit} &= 1 \;
# \end{aligned}
# \]

# %%
if index == 0:
    L_k_crit[0] = k_crit
    L_k_crit[1] = 1
    
elif index == 1:
    L_k_crit[0] = 1
    L_k_crit[1] = k_crit

# %% [markdown]
# ### Nachweise

# %% [markdown]
# **um y-Achse**

# %%
# %%render 2
# if k_crit == 1 and lamb_rel_y < 0.3: eta_y = (sigma_cd/f_c0d)**2 + 1*sigma_myd/f_myd + 0.7*sigma_mzd/f_mzd # EC5 Abs. 6.2.4: Biegung m/o Druck ohne Knicken ohne Kippen
# elif k_crit == 1 and lamb_rel_y > 0.3: eta_y = (sigma_cd)/(f_c0d*k_c_y) + 1*sigma_myd/f_myd + 0.7*sigma_mzd/f_mzd # EC5 Abs. 6.3.2: Biegung m/o Druck mit Knicken ohne Kippen
# elif k_crit < 1: eta_y = (sigma_cd)/(f_c0d*k_c_y) + (sigma_myd/(f_myd*k_crit)) + (sigma_mzd/(f_mzd))**2 # EC5 Abs. 6.3.3: Biegung m/o Druck mit Knicken und Kippen
# Out:
# \[
# \begin{aligned}
# &\text{Since, } k_{crit} = 1 \rightarrow \left( 1 = 1 \right) : \; \;\textrm{(EC5 Abs. 6.3.2: Biegung m/o Druck mit Knicken ohne Kippen)} \end{aligned}
# \]
# \[
# \begin{aligned}
# \eta_{y} &= \frac{ \sigma_{cd} }{ f_{c0d} \cdot k_{c_{y}} } + 1 \cdot \frac{ \sigma_{myd} }{ f_{myd} } + 0.7 \cdot \frac{ \sigma_{mzd} }{ f_{mzd} } \\&= \frac{ 10000.00 }{ 17230.77 \cdot 0.98 } + 1 \cdot \frac{ 3750.00 }{ 17230.77 } + 0.7 \cdot \frac{ 1800.00 }{ 17230.77 } \\&= 0.88  \\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# #### um z-Achse

# %%
# %%render 2
# if k_crit == 1 and lamb_rel_z < 0.3: eta_z = (sigma_cd/f_c0d)**2 + 0.7*sigma_myd/f_myd + 1*sigma_mzd/f_mzd # EC5 Abs. 6.2.4: Biegung m/o Druck ohne Knicken ohne Kippen
# elif k_crit == 1 and lamb_rel_z > 0.3: eta_z = (sigma_cd)/(f_c0d*k_c_z) + 0.7*sigma_myd/f_myd + 1*sigma_mzd/f_mzd # EC5 Abs. 6.3.2: Biegung m/o Druck mit Knicken ohne Kippen
# elif k_crit < 1: eta_y = (sigma_cd)/(f_c0d*k_c_z) + (sigma_myd/(f_myd*k_crit))**2 + (sigma_mzd/(f_mzd)) # EC5 Abs. 6.3.3: Biegung m/o Druck mit Knicken und Kippen
# Out:
# \[
# \begin{aligned}
# &\text{Since, } k_{crit} = 1 \rightarrow \left( 1 = 1 \right) : \; \;\textrm{(EC5 Abs. 6.3.2: Biegung m/o Druck mit Knicken ohne Kippen)} \end{aligned}
# \]
# \[
# \begin{aligned}
# \eta_{z} &= \frac{ \sigma_{cd} }{ f_{c0d} \cdot k_{c_{z}} } + 0.7 \cdot \frac{ \sigma_{myd} }{ f_{myd} } + 1 \cdot \frac{ \sigma_{mzd} }{ f_{mzd} } \\&= \frac{ 10000.00 }{ 17230.77 \cdot 0.99 } + 0.7 \cdot \frac{ 3750.00 }{ 17230.77 } + 1 \cdot \frac{ 1800.00 }{ 17230.77 } \\&= 0.84  \\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ___
# Berliner Hochschule für Technik (BHT) | Konstruktiver Hoch- und Ingenieurbau (M.Eng.) <br>
# Ingenieurholzbau | Prof. Dr. Jens Kickler | Cal Mense 914553 | September 2022
