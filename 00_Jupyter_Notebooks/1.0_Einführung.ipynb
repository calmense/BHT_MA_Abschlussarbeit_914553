# %% [markdown]
# ![Logo_1.png](attachment:Logo_1.png)

# %% [markdown]
# # Einführung

# %% [markdown]
# ## Motivation der Arbeit

# %% [markdown]
# Das innovative Konzept der Einfachheit und Übersichtlichkeit macht Python seit Jahren zu eine der beliebtesten Einsteigerprogrammiersprachen und wird zunehmend an Hochschulen und Universitäten gelehrt. Python ist kostenlos nutzbar und bietet eine umfangreiche Standardbibliothek, die mit einer Vielzahl an Zusatzmodulen erweitert werden kann. Somit präsentiert Python für fast jedes erdenkliche wissenschaftliche Problem eine zugeschnittene Sammlung von Funktionen an und macht das Programmieren mit Python vor allem in den Bereichen der Datenverarbeitung, des Web-Developments und der Ingenieurswissenschaften zu einer spannenden Innovation. Mit wenig Aufwand können effiziente grafische Benutzeroberflächen erstellt oder Ergebnisse umfangreicher Berechnungen übersichtlich dargestellt werden (vgl. Steyer 2017: 3).
#
# Im Bereich des kommerziellen Bauwesens wird Python in Deutschland trotz alledem erst sehr wenig angewandt. Besonders effizient lässt sich das Programmieren bei sich wiederholenden Prozessen einsetzen. Das Automatisieren einfacher Berechnungen oder kognitiver Routinearbeiten ersparen langfristig gesehen eine Menge Zeit und minimieren dabei die Fehleranfälligkeit.
#
# Die Bearbeitung von immer größeren Datenmengen im Zeitalter der Digitalisierung stellt eine Herausforderung dar, die auch im Bauwesen zu bewerkstelligen gilt. Die rasante technologische Entwicklung in allen beruflichen Bereichen wird dazu führen, dass es ebenso für Ingenieure wichtig werden wird, Kenntnisse im Programmieren zu erlernen. Seit der Einführung von computergestützten statischen Berechnungsverfahren entwickelt sich der Anspruch im Bauwesen dahingehend, dass Bauwerke zunehmend komplexer und anspruchsvoller werden. Die hohen Anforderungen werden aus den Folgen des Klimawandels, wie die daraus resultierende Ressourcenknappheit befeuert, sodass ökonomisches und effizientes Bauen unter Einbeziehung ökologischer Aspekte wichtiger ist denn je.
#
# Im Zuge dessen erfährt auch der Holzbau aufgrund seiner Nachhaltigkeit wieder zunehmend an Popularität und an Vertrauen in der Gesellschaft. Als einzig erneuerbarer Bauwerkstoff wird mit dem Einsatz von Holz eine nachhaltige Entscheidung getroffen, die viele Vorteile mit sich bringt. Neben einer sehr guten ökologischen Bilanz besitzt Bauholz zudem hervorragende mechanische Eigenschaften und schafft ein gesundes Raumklima. Eines der entscheidenden Eigenschaften des Materials ist vor allem die Bindung des klimaschädlichen Kohlenstoffs und dessen Umwandlung in Sauerstoff. Dadurch leistet Holz einen wichtigen Beitrag zum Klimawandel (vgl. Neuhaus 2017: 1).
#
# Aus diesem Grund werden im Rahmen dieser Arbeit das Potenzial von Python mithilfe verschiedener Anwendungsmöglichkeiten praxisnah erläutert. Das Ziel besteht darin, Stärken und Schwächen von Python anhand dieser Anwendungsbeispiele aufzuzeigen und dabei eine Schritt-für-Schritt-Anleitung zu erstellen. Die Beispiele sind so gewählt, dass sie möglichst simpel in die alltägliche Arbeitsweise eines Statikers integriert und zu eigenen Anwendungen und Skripten weiterentwickelt werden können.

# %% [markdown]
# ## Herangehensweise

# %% [markdown]
# Der Anspruch dieser Arbeit ist darin definiert, dass es grundsätzlich als Einsteigerkurs für die Programmiersprache Python konzipiert ist. Anhand von Anwendungsbeispielen werden die Grundlagen des Programmierens aufgezeigt und verschiedene Algorithmen sukzessive aufgebaut, sodass die Arbeit zusammenhängend gelesen werden sollte.
#
# Für das Programmieren von eigenen Anwendungen mit Python sind zu Beginn nur eine Handvoll an Grundlagen notwendig, die immer wieder zum Einsatz kommen. Es gibt ein unzähliges Angebot an verschiedenen kostenlosen Seminaren und Tutorien im Internet, die auf Deutsch und Englisch angeboten werden, die die theoretischen Grundlagen ausführlich und umfangreich erklären. Daher wird im Rahmen dieser Arbeit ein praktischer Ansatz gewählt, wobei das Programmieren mit bekannten ingenieurtechnischen Problemstellungen aufgeschlüsselt wird. Anhand dessen wird der Leser dazu angehalten, trotz weniger Vorkenntnisse die angeführten Beispiele für eigene Zwecke anzuwenden. Erst durch die praktische Anwendung sind schnelle und nachhaltige Erfolge garantiert.
#
# ### Formate <br>
# Die Arbeit wird als gebundenes Exemplar und als PDF-Datei abgegeben. Zusätzlich wird die gesamte Arbeit im Sinne der Quelloffenheit inhaltsgleich in Form von Web-basierten und interaktiven Arbeitsblättern auf der Cloud-basierten Entwicklungsplattform **GitHub** online bereitgestellt. Diese werden mit der Programmierumgebung **Jupyter Notebook** verfasst und können als alleinstehendes Dokument gelesen werden.
#
# Das Erstellen und Freigeben von wissenschaftlichen Dokumenten mit Jupyter Notebook eignet sich besonders, um Code mit Texten und Visualisierungen zu erklären. Es wird ermöglicht, dass die demonstrierten Algorithmen aktiv von Nutzern ausprobiert werden können und führt dazu, dass die Kenntnisse auf einer interaktiven Art und Weise vermittelt und erlernt werden.
#
# **Link zu GitHub** <br>
# [GitHub: Cal Mense](https://github.com/calmense)<br>

# %% [markdown]
# ![image.png](attachment:image.png)
# <center> Abbildung 1: Ausschnitt von GitHub </center> <br>

# %% [markdown]
# Die Abbildung zeigt die drei Repositorien der Plattform GitHub. Die Arbeitsblätter im *Ordner 00_Jupyter_Notebooks* haben das Format „.ipynb“ und können dort geöffnet und gelesen werden. Um die Programmierungen anwenden zu können, müssen die Ordner in der Gesamtheit als Zip-Datei heruntergeladen werden.  Die Jupyter Notebook-Dateien können schließlich in der Entwicklerumgebung **Anaconda Distribution** für eigene Zwecke ausprobiert und weiterentwickelt werden. Die Installation von Anaconda wird in Kapitel 2.2 behandelt. Die Ordnerstruktur darf aufgrund der Datei-Abhängigkeiten nicht verändert werden. Im weiteren Verlauf wird auf die zugehörigen Arbeitsblätter verwiesen.
#
# ### Ordnerstruktur
#
# Folgende Dateien sind den Repositorien zu entnehmen:
#
# **00_Jupyter_Notebooks:**
#
# - Thematisch gegliederte Spiegelung der Masterarbeit als Jupyter Notebooks
# - Liste der Bibliotheken: requirements.txt
#
#
# **01_Stützenbemessung_ec5_63:**
#
# -	Excel-Stützenbemessungsprogramm: Stützenbemessung_ec5_63.xlsm
# -	Ordner: **00_Programmhandbuch**:
#     -	Stützenbemessung_ec5_63_Handbuch.ipynb <br>
#
# -	Ordner: **01_Funktionen**:
#     -	Stützenbemessung_ec5_63.py (Quellcode) <br>
#
# -	Ordner: **02_PDF_Ausgaben**:
#     - 	Stützenbemessung_ThII_S-201.pdf (Beispielausdruck) <br>
#
# -	Ordner: **03_Statiknachweise**:
#     -	ec5_63_Stützenbemessung_Ersatzstabverfahren.ipynb
#     -	ec5_63_Stützenbemessung_Theorie II. Ordnung.ipynb <br>
#
#
#
#
# **02_Schraubenbemessung_ec5_87:**
#
# -	Link zum Schraubenbemessungsprogramm
# -	schraubenbemessung_ec5_87.py (Quellcode)
# -	schraubenbemessung_ec5_87_functions.py (Quellcode)
# -	Liste der Bibliotheken: requirements.txt
# -	Grafik-Dateien
# -	Ordner: **00_Programmhandbuch**:
#     -	Schraubenbemessung_ec5_87_Handbuch.ipynb <br>
#
# -	Ordner: **01_Statiknachweise**:
#     -	ec5_87_Schraubenbemessung_Einzelnachweis.ipynb
#     -	ec5_87_Schraubenbemessung_Bemessungstabellen.ipynb <br>

# %% [markdown]
# ## Überblick der Anwendungsbeispiele
#
# Die Anwendungsbeispiele lassen sich grob in folgende 3 Themen aufteilen:
#
# **1.	Integration von Python in Excel <br>**
# Erstellung eines Stützenbemessungsprogramms nach dem Eurocode 5<br>
#
# **2.	Entwicklung einer Webapplikation mit Python und Streamlit <br>**
# Programm für die Berechnung von Tragfähigkeiten von Vollgewindeschrauben<br>
#
# **3.	Erstellung von interaktiven Datenblättern mit Jupyter Notebook <br>**
# Statikberechnungsvorlage für Bemessungen nach dem Eurocode 5<br>

# %% [markdown]
# ![image.png](attachment:image.png)
# <center> Abbildung 2: Verwendete Programme für Anwendungsbeispiele </center> <br>

# %% [markdown]
# ### Integration von Python in Excel
#
# Als Ingenieur ist es stets von großer Bedeutung, die Berechnungen inhaltlich zu verstehen und Ergebnisse anhand des eigenen Fachwissens zu hinterfragen. Trotz der Anwendung diverser Programme und Softwares sollte das Verständnis und das Vertrauen der Berechnungen niemals geringer ausfallen.
#
# Das Arbeiten mit dem Tabellenkalkulationsprogramm Microsoft Excel bietet aus diesen Gründen enorme Vorteile als Ingenieur, um leistungsstark und effizient Dateien zu erstellen und zu bearbeiten. Es können intuitive Berechnungstabellen erzeugt werden, die flexibel angepasst und von anderen Nutzern leicht nachvollzogen werden können. Vor allem in der Buchhaltung, der Finanzwelt und im Ingenieurswesen ist Excel nicht mehr wegzudenken und genießt ein hohes Maß an Vertrauen bei den Nutzern.
#
# Bei komplexeren und größeren Datenmengen kann es jedoch dazu führen, dass sich die Ausführung von Excel verlangsamt und das Arbeiten dadurch stark beeinträchtigt wird. Eines der Hauptursachen stellen eine hohe Anzahl an Formeln und Zellenreferenzen dar, die in großen Tabellen dazu führt, dass die Geschwindigkeit der Datenverarbeitung dadurch abnimmt.
#
# Aus diesem Grund soll im ersten Anwendungsbeispiel aufgezeigt werden, wie durch das Verknüpfen von Excel mit Python ein Stützenbemessungsprogramm entsteht, welches die aufgeführten Aspekte miteinander vereint. Im Sinne der Nachvollziehbarkeit sollen Zwischenergebnisse angezeigt werden und es soll hinzu ermöglicht werden, dass durch das Nutzen von Eingabeparametern eine Interaktion mit dem Nutzer erzielt wird. Die Berechnung selbst übernimmt das Python-Skript, welches innerhalb der Excel-Oberfläche mit einem Schalter ausgeführt wird. Das Ergebnis wird anschließend an Excel übermittelt, sodass keine komplizierten Formeln benötigt werden.
#
# Das Stützenbemessungsprogramm soll einen gesamten Arbeitsablauf von der Bemessung, Optimierung, bis hin zur Dokumentation abbilden.

# %% [markdown]
# ![image_workflow_st-2.png](attachment:image_workflow_st-2.png)
# <center> Abbildung 3: Schematischer Ablauf des Stützenbemessungsprogramms mit Python </center> <br>

# %% [markdown]
# ### Entwicklung einer Webapplikation mit Streamlit
#
# Im zweiten Anwendungsbeispiel soll ein Programm entwickelt werden, welches die Tragfähigkeiten von Vollgewindeschrauben des Herstellers Würth berechnet. Die Berechnungen der Tragfähigkeiten eines Verbindungsmittels hinsichtlich einer Axial- und Scherbeanspruchung ist in der DIN EN 1995-1-1 Absatz 8 geregelt. Durch die hohe Anzahl der Einflussparameter und herstellerspezifischen Materialkennwerte erweist sich die Bemessung als vergleichsweise komplex und kompliziert. Aus diesem Grund gibt es herstellereigene Programme, die verschiedene Holzverbindungen nachweisen. Als Alternative werden Bemessungstafeln angeboten, anhand dessen die Axial- und die Schertragfähigkeiten der Schrauben unter Berücksichtigung gewisser Randbedingungen, wie Seitenholzdicke oder Holzgüte abgelesen werden können.
#
# Die Nutzung der herstellereigenen Programme und Tabellen ist vor allem bei häufiger Nutzung zeitintensiv und stellt eine Arbeitsweise dar, die verbesserungsfähig ist. Mit der Python-Bibliothek Streamlit soll daher eine Webapplikation für die Bemessung von Vollgewindeschrauben entwickelt werden.
#
# Bei ***Streamlit*** handelt es sich um eine Bibliothek eines Drittanbieters, der sich mit interaktiven webbasierten Applikationen beschäftigt. Mit wenig Aufwand können benutzerfreundliche Oberflächen erstellt werden, die anschließend als Programm exportiert und öffentlich geteilt werden können. Streamlit soll daher genutzt werden, um ein Bemessungsprogramm zu schreiben, welche die Schwächen der existierenden Tools aufgreift und eine simple Möglichkeit darbietet Vollgewindeschrauben zu bemessen.

# %% [markdown]
# ![image_workflow_vg.png](attachment:image_workflow_vg.png)
# <center> Abbildung 4: Schematischer Ablauf der Entwicklung des Schraubenbemessungsprogramms mit Python </center> <br>

# %% [markdown]
# ### Erstellung von interaktiven Datenblättern mit Jupyter Notebook
# Für die Aufbereitung des Codes in Jupyter Notebook wird das Modul **handcalcs** verwendet, welches das automatische Rendern bzw. Formatieren von mathematischen Formeln in **Latex** ermöglicht. Jupyter Notebook bietet zudem eine Funktion an, um die Code-Zeilen zu verstecken, sodass übersichtliche statische Bemessungsvorlagen erstellt werden können, die eine vielseitig anwendbare und leistungsstarke Alternative zu herkömmlichen Programmen, wie Excel oder Word darstellen.

# %% [markdown]
# ![gif_statikvorlage_bsp.gif](attachment:gif_statikvorlage_bsp.gif)
# <center> Abbildung 5: Ausschnitt aus Jupyter Notebook</center> <br>

# %% [markdown]
# Zusätzlich werden **Statikvorlagen** erstellt, die als Einzelnachweise zur Bemessung herangezogen werden können. Diese sind in den Ordnern der Anwendungsbeispiele unter 03_Statiknachweise zu finden (s. Kapitel „Ordnerstruktur") und können auf GitHub heruntergeladen und für eigene Zwecke verwendet werden.

# %% [markdown]
# # Literaturverzeichnis
#
# [1] Neuhaus, Helmuth (2017): Ingenieurholzbau, Grundlagen – Bemessung – Nachweise - Beispiele, 4. Aufl., Münster, Deutschland: Springer Vieweg.
#
# [2] Steyer, Ralph (2017): Programmierung in Python, 1. Aufl., Bodenheim, Deutschland: Springer Vieweg.

# %% [markdown]
# ___
# Berliner Hochschule für Technik (BHT) | Konstruktiver Hoch- und Ingenieurbau (M.Eng.) <br>
# Ingenieurholzbau | Prof. Dr. Jens Kickler | Cal Mense 914553 | September 2022
