# %% [markdown]
# ![Logo_3.png](attachment:Logo_3.png)

# %% [markdown]
# # Anwendungsbeispiel 2: Schraubenbemessung

# %% [markdown]
# ## Einführung
#
# Im Folgenden soll ein Web-basiertes Bemessungstool für Vollgewindeschrauben entwickelt werden, welches mit der Bibliothek Streamlit erstellt wird.

# %% [markdown]
# ![image.png](attachment:image.png)
# <center> Abbildung 1: Streamlit Logo </center> <br>

# %% [markdown]
# **Streamlit** ist darauf spezialisiert, schnell und einfach interaktive Webseiten zu programmieren. Besonders gut ist es geeignet, um Ergebnisse auf eine moderne und interaktive Art und Weise darzustellen. Dabei können verschiedene Module, wie *matplotlib*, *plotly* oder *pandas* integriert und grafische Darstellungen und Tabellen eingefügt werden. Außerdem wird eine einfache Methode angeboten, um mit Latex formatierte Formeln darzustellen. In Verbindung mit Github ist es bei Bedarf zusätzlich möglich, die Anwendung als eigenständige Applikation zu exportieren und mit Anderen freizugeben (vgl. Streamlit Inc.: 2022).
#
# **Link zum Schraubenbemessungsprogramm** <br>
# [Schraubenbemessung nach EC5 Abs. 8.7](https://c-02-schraubenbemessung-ec5-87schraubenbemessung-ec5-87-bixfit.streamlitapp.com/)<br>
#
# Das Programm wird so konzipiert, dass die Ermittlung der benötigten Schraube in drei Schritten erfolgt.
#
# 1)	Zunächst können in der Seitenleiste die **Eingangsparameter** hinsichtlich der Verbindung, der Einwirkung und der vorhandenen Bauteildicken eingegeben werden.

# %% [markdown]
# ![image-5.png](attachment:image-5.png)<br>
# <center> Abbildung 2: Schraubenbemessungsprogramm </center> <br>

# %% [markdown]
# 2) Im zweiten Schritt wird die Tragfähigkeit aller angebotenen Schrauben in Bemessungstabellen und -diagrammen dargestellt. Anhand von interaktiven **Filtern** kann nun angezeigt werden, welche Schraube für die angegebene Einwirkung und Bauteilgeometrie zur Bemessung herangezogen werden kann.

# %% [markdown]
# ![image-5.png](attachment:image-5.png)
# <center> Abbildung 3: Anwendung der interaktiven Filter in Tabelle </center> <br>

# %% [markdown]
# ![image-6.png](attachment:image-6.png)
# <center> Abbildung 4: Anwendung der interaktiven Filter in Diagramm </center> <br>

# %% [markdown]
# 3) Ist eine Schraube gewählt worden, kann im letzten Schritt ein **Einzelnachweis** geführt werden. Dieser beinhaltet die ausführliche Berechnung der Tragfähigkeit und kann für die Dokumentation verwendet werden.

# %% [markdown]
# ![image-7.png](attachment:image-7.png) <br>
# <center> Abbildung 5: Einzelnachweis mit Latex-Formeln </center> <br>

# %% [markdown]
# ## Grundlagen zur Bemessung von Holzschrauben
# ### Einleitung
#
# In den folgenden Kapiteln werden verschiedene Anwendungsbeispiele angeführt, die die Tragfähigkeit von Vollgewindeschrauben nach der DIN EN 1995-1-1: 2010-12 Absatz 8 ermitteln. Vollgewindeschrauben gehören mit Stabdübeln, Passbolzen, Bolzen, Gewindestangen und Nägeln zu den metallischen stiftförmigen Verbindungsmitteln. Die Tragfähigkeit wird grundsätzlich hinsichtlich einer Beanspruchung rechtwinklig (Abscheren) und in Richtung (Herausziehen) der Längsachse untersucht. Beim Abscheren wird das Verbindungsmittel auf Biegung beansprucht und überträgt Scherkräfte über Lochleibungsspannungen in das Holz. In Stabachse werden Zugkräfte durch die Verzahnung des Gewindes übertragen (vgl. Neuhaus 2017: 393).
#
# ![image_vg.png](attachment:image_vg.png) <br>
# <center> Abbildung 6: Vollgewindeschraube <br>
#
# Holzschrauben müssen den Standards der Produktnormen DIN EN 14592: 2009-02 und 2012-11.1 entsprechen und benötigen bei Abweichungen einen bauaufsichtlichen Verwendbarkeitsnachweis (vgl. Neuhaus 2017: 466). Für die nachfolgenden Betrachtungen wird eine selbstbohrende Vollgewindeschraube der Firma Würth (ASSY plus VG) verwendet, die in der Europäischen Technischen Zulassung ETA-11/0190 zertifiziert ist.
#
# Im Holzbau ist die Wahl und die Art der Verbindungsmittel maßgebend entscheidend für die Bauteilabmessungen. Sie vereinen Tragelemente zu statischen Tragstrukturen und können auf unterschiedlicher Weise ausgeführt werden. Grundsätzlich können Verbindungsmittel nach ihrer Anwendung und nach ihrer Nachgiebigkeit unterschieden werden. Im Holzingenieurbau kommen meist Verbindungen, wie Stahlformen, und mechanische Verbindungen, wie Nägel und Schrauben zum Einsatz. Die Nachgiebigkeit einer Verbindung entspricht der Steifigkeit bei mechanischer Belastung und hat einen entscheidenden Einfluss auf die globalen Verformungen eines Bauwerks (vgl. Becker/Rautenstrauch 2012: 92).
#
# Hinzu trägt die Konzeptionierung der Holzverbindungen zur Zirkularität eines Gebäudes bei, da bei der Verwendung von einfachen Stahlverbindungen eine Rückbaubarkeit ermöglicht wird, sodass nach dem Lebenszyklus die Materialien in die Kreislaufwirtschaft wieder eingeführt werden können.

# %% [markdown]
# ### Axialtragfähigkeit
#
# Die folgende Abbildung zeigt eine Verbindung eines Balkens mit einem Unterzug und den Einsatz einer Zugschraube. Der Balken lagert auf einer Auflagerfläche und überträgt quer zur Faserrichtung eine Druckkraft. Durch die exzentrische Krafteinleitung entsteht ein Torsionsmoment im Unterzug **(1)**. Dieses Moment löst eine Kippbewegung aus, welches das Auflager des Balkens entziehen würde. Durch die Platzierung der Holzschraube im unteren Zugbereich **(2)**, wird das Torsionsmoment über einen vertikalen Hebelarm in eine Zug- und Druckkomponente abgebaut, sodass eine biegesteife Verbindung gewährleistet wird.
#
# ![03_Jupyter_Notebook_Images-2.png](attachment:03_Jupyter_Notebook_Images-2.png)
# <center> Abbildung 7: Beispiel einer Zugschraube </center><br>
#
#
# Die Bemessung des Widerstandes einer Holzschraube in Stabachse nach dem Eurocode 5 Abs. 8.7.2 erfolgt, indem verschiedene Versagensfälle miteinander verglichen werden, wobei der kleinste Wert maßgebend ist (vgl. DIN EN 1995-1-1:2010-12 2010: 81).
#
# 1.	Herausziehen des Gewindes
# 2.	Zugtragfähigkeit des Stahls
# 3.	Durchziehwiderstand des Schraubenkopfes
# 4.	Abreißwiderstand des Kopfes bei kombinierten Verbindungen mit Stahlblechen

# %% [markdown]
# ![03_Jupyter_Notebook_Images2-2.png](attachment:03_Jupyter_Notebook_Images2-2.png)
# <center> Abbildung 8: Versagensmechanismen von Vollgewindeschrauben </center><br>
#
# Im Wesentlichen sind folgende Parameter für die Axialtragfähigkeit erforderlich (vgl. Becker/Rautenstrauch 2012: 96):
#
# - charakteristischer Wert des Ausziehparameters $𝑓_{𝑎𝑥𝑘}$
# - charakteristischer Wert des Kopfdurchziehparameters $𝑓_{ℎ𝑒𝑎𝑑𝑘}$
# - Winkel zur Faserrichtung 𝛼
# - Rohdichtekennwert des Baustoffes $𝜌_𝑘$
# - Durchmesser des Verbindungsmittels d
# - Bauteildicken $𝑡_1$ und die effektive Länge des Gewindes $𝑙_{𝑒𝑓}$
#
# Diese Parameter sind teils herstellerspezifisch und müssen der Europäischen Technischen Zulassung ETA-11/0190 für Würth Schrauben entnommen werden (vgl. Deutsches Institut für Bautechnik 2013: 11 ff.).

# %% [markdown]
# #### Eingangswerte
# **Bibliotheken** <br>
# Zu Beginn werden die Bibliotheken wie bereits erläutert geordnet und alphabetisch sortiert importiert.

# %%
from math import sqrt, cos, sin, pi    # Mathematische Funktionen
import pandas as pd    # Datenstrukturen und DataFrames
import handcalcs.render    # Darstellung formatierter Gleichungen

# %% [markdown]
# **Kennwerte** <br>
# Es ist zu beachten, dass sich der Kopfdurchmesser und charakteristische Kopfdurchziehparameter je nach Ausführung der Schraube unterscheiden. Die Kennwerte der Schraube werden zunächst in verschachtelten Listen gespeichert und nach dem Durchmesser sortiert.

# %%
# Listen der herstellerspezifischen Kennwerte für Würth ASSY plus VG
## Liste der Durchmesser [mm]
L_d = [6, 8, 10, 12]

## Liste der Schraubenlängen [mm]
L_L = [[120,140,160,180,200,220,240,260], 
       [120,140,160,180,200,220,240,260,280,300,330,380,430,480,530,580], 
       [120,140,160,180,200,220,240,260,280,300,320,340,360,380,400,430,480,530,580,600,650,700,750,800], 
       [120,140,160,180,200,220,240,260,280,300,380,480,600]]

## Liste der char. Ausziehparameter [N/mm^2]
L_f_axk = [11.5, 11, 10, 10]

## Liste der Zugtragfähigkeiten [kN]
L_f_tensk = [11, 20, 32, 45]

## Liste der Kopfdurchmesser [mm]
L_d_h = [14, 22, 25.2, 29.4]

## Liste der char. Kopfdurchziehparameter [N/mm^2]
L_f_head = [13, 13, 10, 10]

# %% [markdown]
# **Eingabewerte** <br>
# Für eine Beispielberechnung werden folgende Eingabewerte definiert:

# %%
# Eingabewerte
d = 6    # mm
L = 240    # mm
t_1 = 100    # mm
t_Blech = 0    # mm
rho_k = 350    # kg/m^3
alpha = 15

# %% [markdown]
# Mit der Ermittlung des Indexes für den Schraubendurchmesser, also der Position in der Liste, können die entsprechenden Kennwerte aus den Listen entnommen werden. Zusätzlich wird die effektive Eindringtiefe der Schraube berechnet. Die effektive Länge $𝑙_{𝑒𝑓}$ entspricht dem Mindestwert aus der Gewindelänge im zweiten Seitenholz und der Dicke des ersten Seitenholzes 𝑚𝑖𝑛(𝐿−$𝑡_1$, $𝑡_1$) (s. Abbildung 5).

# %%
# Bearbeitung der Eingabwerte
index = L_d.index(d)

d_h = L_d_h[index]
f_headk = L_f_head[index]
f_axk = L_f_axk[index]
f_tensk = L_f_tensk[index]
l_ef = min(L-t_1, t_1)
alph = alpha*pi/180

# %% [markdown]
# Für eine Zugbeanspruchung der Schraube werden nun die folgenden 3 Versagensmechanismen untersucht und die Tragfähigkeit berechnet.

# %% [markdown]
# ### Ausziehwiderstand
#
# In Abschnitt A.1.3.1 der ETA ist der charakteristische Wert der Ausziehtragfähigkeit für Vollholz, Brettschichtholz, Brettsperrholz oder Furnierschichtholz definiert. Der Winkel zur Faserrichtung von 0° ≤ 𝛼 ≤ 90° wird mit einem Faktor $𝑘_{𝑎𝑥𝑘}$ berücksichtigt.

# %%
##Ausziehwiderstand
if alpha <= 45:
    k_axk = 0.3+(0.7*alpha)/45
else:
    k_axk = 1

# %%
# %%render 2
# F_axrk1 = (k_axk*f_axk*d*l_ef) * (rho_k/350)**0.8 #N
# F_axRk1 = F_axrk1/1000 #kN
# Out:
# \[
# \begin{aligned}
# F_{axrk1} &= \left( k_{axk} \cdot f_{axk} \cdot d \cdot l_{ef} \right) \cdot \left( \frac{ \rho_{k} }{ 350 } \right) ^{ 0.8 }  = \left( 0.53 \cdot 11.50 \cdot 6 \cdot 100 \right) \cdot \left( \frac{ 350 }{ 350 } \right) ^{ 0.8 } &= 3680.00 \; \;\textrm{(N)}
# \\[10pt]
# F_{axRk1} &= \frac{ F_{axrk1} }{ 1000 }  = \frac{ 3680.00 }{ 1000 } &= 3.68 \; \;\textrm{(kN)}
# \end{aligned}
# \]

# %% [markdown]
# ### Kopfdurchziehwiderstand
#
# Der Widerstand der Schraube gegen das Kopfdurchziehen $F_{headRk}$ ist abhängig von der Querdruckspannung, die zwischen Schraubenkopf und Holz auftritt und errechnet sich aus dem Kopfdurchziehparameter $f_{headk}$ und dem Kopfdurchmesser $d_{h}$.

# %%
# %%render 2
# F_headrk = f_headk*d_h**2*(rho_k/350)**0.8 #N
# F_headRk = F_headrk/1000 #kN
# Out:
# \[
# \begin{aligned}
# F_{headrk} &= f_{headk} \cdot \left( d_{h} \right) ^{ 2 } \cdot \left( \frac{ \rho_{k} }{ 350 } \right) ^{ 0.8 }  = 13 \cdot \left( 14 \right) ^{ 2 } \cdot \left( \frac{ 350 }{ 350 } \right) ^{ 0.8 } &= 2548.00 \; \;\textrm{(N)}
# \\[10pt]
# F_{headRk} &= \frac{ F_{headrk} }{ 1000 }  = \frac{ 2548.00 }{ 1000 } &= 2.55 \; \;\textrm{(kN)}
# \end{aligned}
# \]

# %% [markdown]
# ### Zugfestigkeit
#
# Die Zugfestigkeit einer Schraube ergibt sich für die entsprechende Festigkeitsklasse aus dem Produkt der Zugfestigkeit $f_{ub}$ und dem Schraubenquerschnitt $A$.

# %%
# %%render 2
# F_tRk = f_tensk #kN
# Out:
# \[
# \begin{aligned}
# F_{tRk} &= 11 \; \;\textrm{(kN)}
# \end{aligned}
# \]

# %% [markdown]
# ### Resultierende Axialtragfähigkeit
#
# Bei Kombinationen mit Stahlblechen und Unterlegscheiben oder bei einer Seitenholzdicke größer als 4-mal der Schraubendurmesser $t_1 > 4d$ ist das Versagen infolge Kopfdurchziehen zu vernachlässigen.

# %%
# Axialtragfähigkeit einer Vollgewindeschraube
## Bei Kombinationen mit Stahlblechen/Unterlegscheiben oder bei t_1 > 4d ist das Versagen\
## infolge Kopfdurchziehen zu vernachlässigen
if t_Blech != 0 or t_1 > 4*d:
    F_axRk = min(F_axRk1, F_tRk) #kN
    F_axrk = min(F_axrk1, F_tRk*1000) #N

elif t_Blech == 0 or t_1 < 4*d:
    F_axRk = min(F_axRk1, F_headRk, F_tRk) #kN
    F_axrk = min(F_axrk1, F_headrk, F_tRk*1000) #N

# %%
# %%render 2
# F_axRk    # kN - Axialtragfähigkeit
# Out:
# \[
# \begin{aligned}
# F_{axRk} &= 3.68 \; \;\textrm{(kN - Axialtragfähigkeit)}
# \end{aligned}
# \]

# %% [markdown]
# ## Tragfähigkeit auf Abscheren
#
# Rechtwinklig zur Stabachse wird bei der Ermittlung der Tragfähigkeit unterschieden in reine Holz-Holzverbindungen und Stahlblech-Holzverbindungen, die ein- oder mehrschnittig ausgeführt werden können. Die Tragfähigkeit auf Abscheren wird in der Scherfuge nachgewiesen und berücksichtigt die Einflüsse der Lochleibungsfestigkeit, die Fließgrenze und des Ausziehwiderstandes des Verbindungsmittels. Als Berechnungsmodell wird für diese Versagensmechanismen ein ideal-plastisches Verhalten zugrunde gelegt. Diese Vereinfachung beinhaltet, dass elastische Verformungen vernachlässigt werden. Im Eurocode 5 dient die sogenannte Fließgelenktheorie nach Johansen die Grundlage für die Bemessung von stiftförmigen Verbindungsmitteln (vgl. Becker/Rautenstrauch 2012: 96).
#
# Es sind folgende Parameter erforderlich:
#
# - charakteristischer Wert der Lochleibungsfestigkeit $f_{hk}$
# - charakteristisches Fließmoment $M_{yRk}$
# - Winkel zur Faserrichtung $\alpha$
# - Rohdichtekennwert des Baustoffes $\rho_{k}$
# - Bauteildicken $t_{1}$
# - Durchmesser des Verbindungsmittels d
#
# In den kommenden Beispielen wird von derselben Holzrohdichte in beiden Seitenhölzern ausgegangen, sodass für die Lochleibungsfestigkeit $f_{hk} = f_{1hk} = f_{2hk}$ gilt. Der Winkel zur Faserrichtung $\alpha$ muss als Bogenmaß umgerechnet werden.

# %% [markdown]
# Der Nachweis eines Verbindungsmittels je Scherfuge berücksichtigt demnach verschiedene Versagensmechanismen.
# Für eine einschnittige Holz-Holzverbindung werden folgende mögliche Mechanismen betrachtet:
#
# - **Versagen durch Überschreitung der Lochleibungsfestigkeit des Holzes: keine Verformung des Verbindungsmittels**
#
#     1) Lochleibung Seitenholz 1
#
#     2) Lochleibung Seitenholz 2
#
#     3) Lochleibung in beiden Seitenhölzern <br>
#
#
# - **Versagen durch Fließgelenkbildung: plastisches Biegeversagen mit plastischer Verformung** <br>
# (bei größeren Holzdicken, höchste Tragfähigkeit und duktiles Bauteilversagen)
#
#     4) Plastisches Moment im Seitenholz 2
#
#     5) Plastisches Moment im Seitenholz 1
#
#     6) Plastisches Moment in beiden Seitenhölzern <br>

# %% [markdown]
# ![image_abscheren.png](attachment:image_abscheren.png)
# <center> Abbildung 9: Versagensmechanismen von Vollgewindeschrauben auf Abscheren </center><br>

# %% [markdown]
# **Winkel zwischen Kraft- und Faserrichtung** <br>
# Vor allem bei der Betrachtung der Lochleibungsfestigkeit spielt der Winkel zwischen Kraft und Faserrichtung eine bedeutende Rolle, da die Lochleibungsfestigkeit mit steigendem Winkel abnimmt. Folglich ist sie bei 0 Grad am größten. Dies wird wie folgt berücksichtigt.

# %%
# %%render short
# f_hk = (0.082*rho_k*d**(-0.3))/(2.5*cos(alph)**2+sin(alph)**2) #$N/mm^2$
# Out:
# \[
# \begin{aligned}
# f_{hk} &= \frac{ 0.082 \cdot \rho_{k} \cdot \left( d \right) ^{ \left( - 0.3 \right) } }{ 2.5 \cdot \left( \cos \left( \mathrm{alph} \right) \right) ^{ 2 } + \left( \sin \left( \mathrm{alph} \right) \right) ^{ 2 } }  = \frac{ 0.082 \cdot 350 \cdot \left( 6 \right) ^{ \left( - 0.3 \right) } }{ 2.5 \cdot \left( \cos \left( 0.262 \right) \right) ^{ 2 } + \left( \sin \left( 0.262 \right) \right) ^{ 2 } } &= 6.987 \; \;\textrm{($N/mm^2$)}
# \end{aligned}
# \]

# %%
# %%render 2
# M_yrk = 0.15*600*d**(2.6) #$Nmm$ - Plastisches Moment
# Out:
# \[
# \begin{aligned}
# M_{yrk} &= 0.15 \cdot 600 \cdot \left( d \right) ^{ 2.6 }  = 0.15 \cdot 600 \cdot \left( 6 \right) ^{ 2.6 } &= 9493.71 \; \;\textrm{($Nmm$ - Plastisches Moment)}
# \end{aligned}
# \]

# %% [markdown]
# ### Einschnittige Holz-Holzverbindung

# %% [markdown]
# #### Lochleibungsversagen
#
# Beim Lochleibungsversagen findet keine Verformung im Holz statt und führt zu einem spröden Bauteilversagen im Holz. Dieses Versagen kann durch eine Steigerung der Bauteildicken vermieden werden.

# %%
# %%render 2
# F_vk1 = f_hk*t_1*d #$N$ - Lochleibungsw. im SH1
# F_Vk1 = F_vk1/1000 #kN
# Out:
# \[
# \begin{aligned}
# F_{vk1} &= f_{hk} \cdot t_{1} \cdot d  = 6.99 \cdot 100 \cdot 6 &= 4192.41 \; \;\textrm{($N$ - Lochleibungsw. im SH1)}
# \\[10pt]
# F_{Vk1} &= \frac{ F_{vk1} }{ 1000 }  = \frac{ 4192.41 }{ 1000 } &= 4.19 \; \;\textrm{(kN)}
# \end{aligned}
# \]

# %%
# %%render 2
# F_vk2 = f_hk*l_ef*d #$N$ - Lochleibungsw. im SH2
# F_Vk2 = F_vk2/1000 #kN
# Out:
# \[
# \begin{aligned}
# F_{vk2} &= f_{hk} \cdot l_{ef} \cdot d  = 6.99 \cdot 100 \cdot 6 &= 4192.41 \; \;\textrm{($N$ - Lochleibungsw. im SH2)}
# \\[10pt]
# F_{Vk2} &= \frac{ F_{vk2} }{ 1000 }  = \frac{ 4192.41 }{ 1000 } &= 4.19 \; \;\textrm{(kN)}
# \end{aligned}
# \]

# %%
# %%render 2
# F_vk3 = (f_hk*t_1*d)/2 * ( sqrt(1+2*(1+l_ef/t_1+(l_ef/t_1)**2)+(l_ef/t_1)**2)-(1+l_ef/t_1))+F_axrk/4 #$N$ - Lochleibungswiderstand in beiden Seitenhölzern
# F_Vk3 = F_vk3/1000 #kN
# Out:
# \[
# \begin{aligned}
# F_{vk3} &= \frac{ f_{hk} \cdot t_{1} \cdot d }{ 2 } \cdot \left( \sqrt { 1 + 2 \cdot \left( 1 + \frac{ l_{ef} }{ t_{1} } + \left( \frac{ l_{ef} }{ t_{1} } \right) ^{ 2 } \right) + \left( \frac{ l_{ef} }{ t_{1} } \right) ^{ 2 } } - \left( 1 + \frac{ l_{ef} }{ t_{1} } \right) \right) + \frac{ F_{axrk} }{ 4 } \\&= \frac{ 6.99 \cdot 100 \cdot 6 }{ 2 } \cdot \left( \sqrt { 1 + 2 \cdot \left( 1 + \frac{ 100 }{ 100 } + \left( \frac{ 100 }{ 100 } \right) ^{ 2 } \right) + \left( \frac{ 100 }{ 100 } \right) ^{ 2 } } - \left( 1 + \frac{ 100 }{ 100 } \right) \right) + \frac{ 3680.00 }{ 4 } \\&= 2656.55 \; \;\textrm{($N$ - Lochleibungswiderstand in beiden Seitenhölzern)}\\[10pt]
# \\[10pt]
# F_{Vk3} &= \frac{ F_{vk3} }{ 1000 }  = \frac{ 2656.55 }{ 1000 } &= 2.66 \; \;\textrm{(kN)}
# \end{aligned}
# \]

# %% [markdown]
# #### Entstehung eines Fließgelenks
#
# Bei größeren Holzdicken erfolgt ein plastisches Biegeversagen mit plastischer Verformung. Dieser Versagensmechanismus resultiert in höhere Tragfähigkeiten und einem duktilen Bauteilversagen.

# %%
# %%render 2
# F_vk4 = 1.05*(f_hk*t_1*d)/(3) * (sqrt(4+(12*M_yrk)/(f_hk*t_1**2*d))-1)+F_axrk/4 #$N$ - Fließgelenk im Seitenholz 1
# F_Vk4 = F_vk4/1000 #kN
# Out:
# \[
# \begin{aligned}
# F_{vk4} &= 1.05 \cdot \frac{ f_{hk} \cdot t_{1} \cdot d }{ 3 } \cdot \left( \sqrt { 4 + \frac{ 12 \cdot M_{yrk} }{ f_{hk} \cdot \left( t_{1} \right) ^{ 2 } \cdot d } } - 1 \right) + \frac{ F_{axrk} }{ 4 } \\&= 1.05 \cdot \frac{ 6.99 \cdot 100 \cdot 6 }{ 3 } \cdot \left( \sqrt { 4 + \frac{ 12 \cdot 9493.71 }{ 6.99 \cdot \left( 100 \right) ^{ 2 } \cdot 6 } } - 1 \right) + \frac{ 3680.00 }{ 4 } \\&= 2485.39 \; \;\textrm{($N$ - Fließgelenk im Seitenholz 1)}\\[10pt]
# \\[10pt]
# F_{Vk4} &= \frac{ F_{vk4} }{ 1000 }  = \frac{ 2485.39 }{ 1000 } &= 2.49 \; \;\textrm{(kN)}
# \end{aligned}
# \]

# %%
# %%render 2
# F_vk5 = 1.05*(f_hk*l_ef*d)/(3) * (sqrt(4+(12*M_yrk)/(f_hk*l_ef**2*d))-1)+F_axrk/4 #$N$ - Fließgelenk im Seitenholz 2
# F_Vk5 = F_vk5/1000 #kN
# Out:
# \[
# \begin{aligned}
# F_{vk5} &= 1.05 \cdot \frac{ f_{hk} \cdot l_{ef} \cdot d }{ 3 } \cdot \left( \sqrt { 4 + \frac{ 12 \cdot M_{yrk} }{ f_{hk} \cdot \left( l_{ef} \right) ^{ 2 } \cdot d } } - 1 \right) + \frac{ F_{axrk} }{ 4 } \\&= 1.05 \cdot \frac{ 6.99 \cdot 100 \cdot 6 }{ 3 } \cdot \left( \sqrt { 4 + \frac{ 12 \cdot 9493.71 }{ 6.99 \cdot \left( 100 \right) ^{ 2 } \cdot 6 } } - 1 \right) + \frac{ 3680.00 }{ 4 } \\&= 2485.39 \; \;\textrm{($N$ - Fließgelenk im Seitenholz 2)}\\[10pt]
# \\[10pt]
# F_{Vk5} &= \frac{ F_{vk5} }{ 1000 }  = \frac{ 2485.39 }{ 1000 } &= 2.49 \; \;\textrm{(kN)}
# \end{aligned}
# \]

# %%
# %%render 2
# F_vk6 = 1.15*sqrt(2*M_yrk*f_hk*d)+F_axrk/4 #$N$ - beide Seitenhölzer
# F_Vk6 = F_vk6/1000 #kN
# Out:
# \[
# \begin{aligned}
# F_{vk6} &= 1.15 \cdot \sqrt { 2 \cdot M_{yrk} \cdot f_{hk} \cdot d } + \frac{ F_{axrk} }{ 4 }  = 1.15 \cdot \sqrt { 2 \cdot 9493.71 \cdot 6.99 \cdot 6 } + \frac{ 3680.00 }{ 4 } &= 1946.04 \; \;\textrm{($N$ - beide Seitenhölzer)}
# \\[10pt]
# F_{Vk6} &= \frac{ F_{vk6} }{ 1000 }  = \frac{ 1946.04 }{ 1000 } &= 1.95 \; \;\textrm{(kN)}
# \end{aligned}
# \]

# %% [markdown]
# #### Resultierende Schertragfähigkeit

# %%
# %%render 2
# F_vrk = min(F_vk1, F_vk2, F_vk3, F_vk4, F_vk5, F_vk6) #N - Resultierende Schertragfähigkeit
# F_Vrk = F_vrk/1000 #kN
# Out:
# \[
# \begin{aligned}
# F_{vrk} &= \operatorname{min} { \left( F_{vk1} ,\  F_{vk2} ,\  F_{vk3} ,\  F_{vk4} ,\  F_{vk5} ,\  F_{vk6} \right) } \\&= \operatorname{min} { \left( 4192.41 ,\  4192.41 ,\  2656.55 ,\  2485.39 ,\  2485.39 ,\  1946.04 \right) } \\&= 1946.04 \; \;\textrm{(N - Resultierende Schertragfähigkeit)}\\[10pt]
# \\[10pt]
# F_{Vrk} &= \frac{ F_{vrk} }{ 1000 }  = \frac{ 1946.04 }{ 1000 } &= 1.95 \; \;\textrm{(kN)}
# \end{aligned}
# \]

# %% [markdown]
# ### Einschnittige Holz-Stahlverbindung (dickes Blech)
# Bei einer Verbindung, bei der die Dicke des Stahlblechs größer als der Schraubendurchmesser ist, wird von einem dicken Stahlblech ausgegangen ($t_{Blech}>d$). In diesem Fall wird das Verbindungsmittel vom Stahlblech eingespannt.

# %%
# %%render 2
# F_vk1 = f_hk*t_1*d  #$N$ - Fließgelenk im Seitenholz 1
# F_Vk1 = F_vk1/1000 #kN
# Out:
# \[
# \begin{aligned}
# F_{vk1} &= f_{hk} \cdot t_{1} \cdot d  = 6.99 \cdot 100 \cdot 6 &= 4192.41 \; \;\textrm{($N$ - Fließgelenk im Seitenholz 1)}
# \\[10pt]
# F_{Vk1} &= \frac{ F_{vk1} }{ 1000 }  = \frac{ 4192.41 }{ 1000 } &= 4.19 \; \;\textrm{(kN)}
# \end{aligned}
# \]

# %%
# %%render 2
# F_vk2 = f_hk*t_1*d*(sqrt(2+(4*M_yrk)/(f_hk*d*t_1**2))-1)+F_axrk/4  #$N$ - Fließgelenk im Seitenholz 2
# F_Vk2 = F_vk2/1000 #kN
# Out:
# \[
# \begin{aligned}
# F_{vk2} &= f_{hk} \cdot t_{1} \cdot d \cdot \left( \sqrt { 2 + \frac{ 4 \cdot M_{yrk} }{ f_{hk} \cdot d \cdot \left( t_{1} \right) ^{ 2 } } } - 1 \right) + \frac{ F_{axrk} }{ 4 } \\&= 6.99 \cdot 100 \cdot 6 \cdot \left( \sqrt { 2 + \frac{ 4 \cdot 9493.71 }{ 6.99 \cdot 6 \cdot \left( 100 \right) ^{ 2 } } } - 1 \right) + \frac{ 3680.00 }{ 4 } \\&= 2789.33 \; \;\textrm{($N$ - Fließgelenk im Seitenholz 2)}\\[10pt]
# \\[10pt]
# F_{Vk2} &= \frac{ F_{vk2} }{ 1000 }  = \frac{ 2789.33 }{ 1000 } &= 2.79 \; \;\textrm{(kN)}
# \end{aligned}
# \]

# %%
# %%render 2
# F_vk3 = 2.3*sqrt(M_yrk*f_hk*d)+F_axrk/4 #$N$ - 2 Fließgelenke
# F_Vk3 = F_vk3/1000 #kN
# Out:
# \[
# \begin{aligned}
# F_{vk3} &= 2.3 \cdot \sqrt { M_{yrk} \cdot f_{hk} \cdot d } + \frac{ F_{axrk} }{ 4 }  = 2.3 \cdot \sqrt { 9493.71 \cdot 6.99 \cdot 6 } + \frac{ 3680.00 }{ 4 } &= 2371.03 \; \;\textrm{($N$ - 2 Fließgelenke)}
# \\[10pt]
# F_{Vk3} &= \frac{ F_{vk3} }{ 1000 }  = \frac{ 2371.03 }{ 1000 } &= 2.37 \; \;\textrm{(kN)}
# \end{aligned}
# \]

# %%
# %%render 2
# F_vrk = min(F_vk1, F_vk2, F_vk3) #$N$ - Resultierende Schertragfähigkeit
# F_Vrk = F_vrk/1000 #kN
# Out:
# \[
# \begin{aligned}
# F_{vrk} &= \operatorname{min} { \left( F_{vk1} ,\  F_{vk2} ,\  F_{vk3} \right) }  = \operatorname{min} { \left( 4192.41 ,\  2789.33 ,\  2371.03 \right) } &= 2371.03 \; \;\textrm{($N$ - Resultierende Schertragfähigkeit)}
# \\[10pt]
# F_{Vrk} &= \frac{ F_{vrk} }{ 1000 }  = \frac{ 2371.03 }{ 1000 } &= 2.37 \; \;\textrm{(kN)}
# \end{aligned}
# \]

# %% [markdown]
# ### Einschnittige Holz-Stahlverbindung (dünnes Blech)
# Ein dünnes Stahlblech ist definiert mit einer Dicke kleiner als die Hälfte des Schraubendurchmessers ($t_{Blech}<0,5d$).

# %%
# %%render 2
# F_vk1 = 0.4*f_hk*t_1*d #$N$ - Lochleibungswiderstand im Seitenholz 1
# F_Vk1 = F_vk1/1000 #kN
# Out:
# \[
# \begin{aligned}
# F_{vk1} &= 0.4 \cdot f_{hk} \cdot t_{1} \cdot d  = 0.4 \cdot 6.99 \cdot 100 \cdot 6 &= 1676.96 \; \;\textrm{($N$ - Lochleibungswiderstand im Seitenholz 1)}
# \\[10pt]
# F_{Vk1} &= \frac{ F_{vk1} }{ 1000 }  = \frac{ 1676.96 }{ 1000 } &= 1.68 \; \;\textrm{(kN)}
# \end{aligned}
# \]

# %%
# %%render 2
# F_vk2 = 1.15*sqrt(2*M_yrk*f_hk*d)+F_axrk/4 #$N$ - Fließgelenk im SH
# F_Vk2 = F_vk2/1000 #kN
# Out:
# \[
# \begin{aligned}
# F_{vk2} &= 1.15 \cdot \sqrt { 2 \cdot M_{yrk} \cdot f_{hk} \cdot d } + \frac{ F_{axrk} }{ 4 }  = 1.15 \cdot \sqrt { 2 \cdot 9493.71 \cdot 6.99 \cdot 6 } + \frac{ 3680.00 }{ 4 } &= 1946.04 \; \;\textrm{($N$ - Fließgelenk im SH)}
# \\[10pt]
# F_{Vk2} &= \frac{ F_{vk2} }{ 1000 }  = \frac{ 1946.04 }{ 1000 } &= 1.95 \; \;\textrm{(kN)}
# \end{aligned}
# \]

# %%
# %%render 2
# F_vrk = min(F_vk1, F_vk2) #$N$ - Resultierende Schertragfähigkeit
# F_Vrk = F_vrk/1000 #kN
# Out:
# \[
# \begin{aligned}
# F_{vrk} &= \operatorname{min} { \left( F_{vk1} ,\  F_{vk2} \right) }  = \operatorname{min} { \left( 1676.96 ,\  1946.04 \right) } &= 1676.96 \; \;\textrm{($N$ - Resultierende Schertragfähigkeit)}
# \\[10pt]
# F_{Vrk} &= \frac{ F_{vrk} }{ 1000 }  = \frac{ 1676.96 }{ 1000 } &= 1.68 \; \;\textrm{(kN)}
# \end{aligned}
# \]

# %% [markdown]
# # Literaturverzeichnis
#
# [1] Becker, Klausjürgen / Karl Rautenstrauch (2012): Ingenieurholzbau nach Eurocode 5, Konstruktion, Berechnung, Ausführung, 1. Aufl., Berlin, Deutschland: Ernst & Sohn.
#
# [2] Deutsches Institut für Bautechnik (2013): Europäische Technische Zulassung ETA-11/0190, Würth Schrauben, Berlin, Deutschland: Beuth-Verlag.
#
# [3] DIN EN 1995-1-1:2010-12 (2010): Eurocode 5: Bemessung und Konstruktion von Holzbauten - Teil 1-1: Allgemeines-Allgemeines regeln und Regeln für den Hochbau, Berlin, Deutschland: Beuth-Verlag.
#
# [4] DIN EN 1995-1-1/NA:2010-12 (2010): Nationaler Anhang – National festgelegte Parameter – Eurocode 5: Bemessung und Konstruktion von Holzbauten – Teil 1-1:
# Allgemeines – Allgemeine Regeln und Regeln für den Hochbau, Berlin, Deutschland: Beuth-Verlag.
#
# [5] Neuhaus, Helmuth (2017): Ingenieurholzbau, Grundlagen – Bemessung – Nachweise - Beispiele, 4. Aufl., Münster, Deutschland: Springer Vieweg.

# %% [markdown]
# ---
# Berliner Hochschule für Technik (BHT) | Konstruktiver Hoch- und Ingenieurbau (M.Eng.) <br>
# Ingenieurholzbau | Prof. Dr. Jens Kickler | Cal Mense 914553 | September 2022
